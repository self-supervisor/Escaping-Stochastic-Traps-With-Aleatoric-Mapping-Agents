# %%
import numpy as np
import matplotlib.pyplot as plt 
import glob
# %matplotlib inline

# %%
# plt.imshow(np.log(np.load("frames_8_noisy_tv_True_curiosity_True_uncertainty_False_random_seed_1_coefficient_0.0005_MiniGrid-KeyCorridorS6R3-v0_visitation_counts.npy")))
# plt.colorbar()
# plt.show()
# plt.imshow(np.log(np.load("frames_8_noisy_tv_True_curiosity_False_uncertainty_False_random_seed_1_coefficient_0.0005_visitation_counts.npy")))
# plt.colorbar()
# plt.show()
plt.imshow(np.log((np.load("frames_8000000000000_noisy_tv_True_curiosity_True_uncertainty_True_random_seed_2_coefficient_0.0005_MiniGrid-MultiRoom-N4-S5-v0_visitation_counts.npy"))))
plt.colorbar()
# Out:
# /home/amavorpa/Escaping-Stochastic-Traps-With-Aleatoric-Mapping-Agents/stochastic_traps/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
plt.imshow(np.log(np.load("frames_8_noisy_tv_False_curiosity_True_uncertainty_False_random_seed_1_coefficient_0.0005_MiniGrid-KeyCorridorS6R3-v0_visitation_counts.npy")))
plt.colorbar()
plt.show()
plt.imshow(np.log(np.load("frames_8_noisy_tv_False_curiosity_False_uncertainty_False_random_seed_1_coefficient_0.0005_visitation_counts.npy")))
plt.colorbar()
plt.show()
plt.imshow(np.log(np.load("frames_8_noisy_tv_False_curiosity_True_uncertainty_True_random_seed_1_coefficient_0.0005_MiniGrid-KeyCorridorS6R3-v0_visitation_counts.npy")))
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d7969fd97907> in <module>
# ----> 1 plt.imshow(np.log(np.load("frames_8_noisy_tv_False_curiosity_True_uncertainty_False_random_seed_1_coefficient_0.0005_MiniGrid-KeyCorridorS6R3-v0_visitation_counts.npy")))
#       2 plt.colorbar()
#       3 plt.show()
#       4 plt.imshow(np.log(np.load("frames_8_noisy_tv_False_curiosity_False_uncertainty_False_random_seed_1_coefficient_0.0005_visitation_counts.npy")))
#       5 plt.colorbar()
#
# ~/Escaping-Stochastic-Traps-With-Aleatoric-Mapping-Agents/stochastic_traps/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: 'frames_8_noisy_tv_False_curiosity_True_uncertainty_False_random_seed_1_coefficient_0.0005_MiniGrid-KeyCorridorS6R3-v0_visitation_counts.npy'
